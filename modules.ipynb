# %%
import math
print(math.sqrt(144))
print(math.pi)
# Out:
# 12.0
# 3.141592653589793

# %%
from random import randint
print(randint(1,100))
# Out:
# 78

# %%
# %%writefile calculator.py

def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Error: Division by zero"
    return a / b
# Out:
# Writing calculator.py

# %%
# %%writefile main.py

import calculator

print("Addition:", calculator.add(10, 5))
print("Subtraction:", calculator.subtract(10, 5))
print("Multiplication:", calculator.multiply(10, 5))
print("Division:", calculator.divide(10, 5))
# Out:
# Writing main.py

# %%
# !python main.py
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
import os
print(os.__file__)
print(dir(os))
# Out:
# /usr/lib/python3.12/os.py
# ...

# %%
# %%writefile utilities/__init__.py
# Out:
# Writing utilities/__init__.py

# %%
# %%writefile utilities/string_utils.py

def to_uppercase(text):
    return text.upper()

def reverse_string(text):
    return text[::-1]
# Out:
# Writing utilities/string_utils.py

# %%
# %%writefile utilities/math_utils.py

def square(n):
    return n * n

def cube(n):
    return n * n * n
# Out:
# Writing utilities/math_utils.py

# %%
# %%writefile main.py

from utilities.string_utils import to_uppercase, reverse_string
from utilities.math_utils import square, cube

# String utilities
print("Uppercase:", to_uppercase("hello"))
print("Reversed:", reverse_string("python"))

# Math utilities
print("Square:", square(4))
print("Cube:", cube(3))
# Out:
# Overwriting main.py

# %%
# !python main.py
# Out:
# Uppercase: HELLO
# Reversed: nohtyp
# Square: 16
# Cube: 27

# %%
try:
    import numpy as np
    print("Using numpy for calculations.")

    result = np.sum([1, 2, 3])

except ModuleNotFoundError:
    print("Numpy not found. Using built-in sum() as fallback.")

    result = sum([1, 2, 3])

print("Result:", result)
# Out:
# Using numpy for calculations.
# Result: 6

# %%
try:
    import advanced_math
except ModuleNotFoundError:
    print("advanced_math not available. Loading fallback version.")

    class advanced_math:
        @staticmethod
        def power(a, b):
            return a ** b

print(advanced_math.power(2, 3))
# Out:
# advanced_math not available. Loading fallback version.
# 8
