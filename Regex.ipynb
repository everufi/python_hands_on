# %%
import re
str1=input()
str2=input()
if re.search(str2,str1):
  print("found")
else:
  print("not found")
# Out:
# hey hi helo
# hi
# found

# %%
email=input()
domain=re.search(r'@([\w.]+)',email)
print(domain.group(1))
# Out:
# eve@gmail.com
# gmail.com

# %%
num=input()
new_num=re.sub(r'\d(?=\d{4})',"*", num)
print(new_num)
# Out:
# 12345678
# ****5678

# %%
str1=input()
pattern=r'\d{4}-\d{2}-\d{2}'
if  re.match(pattern,str1):
  print("valid")
else:
  print("invalid")
# Out:
# 2025-11-30 Report Generated
# valid
